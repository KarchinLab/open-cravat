# %% [markdown]
# ## Annotate vcfs with OpenCravat

# %% [markdown]
# ## Define your chromosome!

# %%
chrom = '<insert chromosome here>'
prefix = '<insert file prefix here>'

# %%
# !echo {prefix}.{chrom}.vcf.gz.sqlite

# %% [markdown]
# ### Get chromosomal data

# %%
# !dx download {prefix}.{chrom}.vcf.gz

# %% [markdown]
# ### Run the Annotation!

# %%
# %%bash
# oc run {prefix}.{chrom}.vcf.gz -l hg38 -d cravat_chr{chrom}

# %% [markdown]
# ### Convert to tsv

# %%
# %%bash
# oc report {prefix}.{chrom}.vcf.gz.sqlite -t tsv

# %% [markdown]
# #### Run case_control notebook if desired
